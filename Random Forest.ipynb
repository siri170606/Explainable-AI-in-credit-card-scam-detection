# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
#import the dataset
dataset = pd.read_csv('creditcard.csv')

# %%
X = dataset.drop('Class',axis=1)
Y = dataset['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30)

# %%
# Fit the model
rfc_imb_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50)

# %%
# Predictions on the train set
X_train_prediction = rfc_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(Y_train, X_train_prediction)
print(confusion)
# Out:
# [[198968     44]
#  [    95    257]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_train, X_train_prediction))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_train, X_train_prediction))
# Out:
# Accuracy:- 0.9993027828494613
# Sensitivity:- 0.7301136363636364
# Specificity:- 0.9997789078045545
# F1-Score:- 0.7871362940275651

# %%
# classification_report
print(classification_report(Y_train, X_train_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199012
#            1       0.85      0.73      0.79       352
#
#     accuracy                           1.00    199364
#    macro avg       0.93      0.86      0.89    199364
# weighted avg       1.00      1.00      1.00    199364

# %%
# Predictions on the test set
X_test_prediction = rfc_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(Y_test, X_test_prediction)
print(confusion)
# Out:
# [[85291    12]
#  [   53    87]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(Y_test, X_test_prediction))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(Y_test, X_test_prediction))
# Out:
# Accuracy:- 0.9992392589211521
# Sensitivity:- 0.6214285714285714
# Specificity:- 0.9998593249944316
# F1-Score:- 0.7280334728033473

# %%
# classification_report
print(classification_report(Y_test,X_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85303
#            1       0.88      0.62      0.73       140
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443
